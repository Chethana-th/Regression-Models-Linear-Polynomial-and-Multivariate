# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df= pd.read_csv('canada_income.csv')

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.isnull().sum()
# Out:
# year                       0
# per capita income (US$)    0
# dtype: int64

# %%
 #rename the second column
df.columns = ['year','per_capita_income']
df.head()
# Out:
#    year  per_capita_income
# 0  1970        3399.299037
# 1  1971        3768.297935
# 2  1972        4251.175484
# 3  1973        4804.463248
# 4  1974        5576.514583

# %%
#building the model

X=df[['year']]
y=df[['per_capita_income']]

#initializing the model

model=linear_model.LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
#capital income in year 2030

model.predict([[2030]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[49573.34484664]])

# %% [markdown]
# The capital income in Canada in year 2030 is 49573.34484664 $

# %%
# Predict income for the year 2030
future_year = np.array([[2030]])
future_income = model.predict(future_year)

# Plot the prediction point
plt.scatter(future_year, future_income, color='green', s=100, marker='X', label='2030 Prediction')
plt.text(future_year, future_income, f"${int(future_income)}", fontsize=12)

# Redraw the plot with the prediction
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Regression Line')

plt.title('Linear Regression with 2030 Forecast')
plt.xlabel('Year')
plt.ylabel('Per Capita Income')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Thathsaranie\AppData\Local\Temp\ipykernel_32696\2022630107.py:7: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.text(future_year, future_income, f"${int(future_income)}", fontsize=12)
